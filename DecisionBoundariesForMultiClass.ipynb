# %% [markdown]
# <a href="https://colab.research.google.com/github/whatya-san-j/Machine-Learning-AndrewNg-DeepLearning.AI/blob/MyWorkingBranch/DecisionBoundariesForMultiClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Are decision boundaries always straight lines (or planes)?
# ## Question from ML Satsang 14 Nov 2025 while reviewing C2_W2 SoftMax section.
#
# ## Try it out with real datasets:
# ### easier to visulazie with datasets with just 2 features (to be plotted on x and y axis)
# ### Are there publicly available datasets with just 2 features? - A search provides a link to Iris (plant petal features) data set. Iris is from UCI ML Respository. It also comes with its own Python library to access data.
#
#
# ### Sanjay Nandipaku (SanjayNandipaku@whatya.net)
# ### 15 Nov 2025

# %%
import sys
import site
try:
    import ucimlrepo
    print("ucimlrepo is already installed.")
except ImportError:
    # !pip install ucimlrepo
    print("ucimlrepo was installed.")

    sys.path.append(site.getusersitepackages())
    import ucimlrepo
from ucimlrepo import Error
